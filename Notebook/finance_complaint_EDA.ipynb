# %% [raw]
# ## extracting zip file:
#
# import zipfile
# from io import BytesIO
# from google.cloud import storage
#
# def extract_zip_gcs_to_gcs(zip_file_src, destination_bucket, destination_folder):
#     # initialize the storage client
#     storage_client = storage.Client()
#     bucket = storage_client.bucket(destination_bucket)
#
#     # download the zip file from Google Cloud Storage
#     zip_blob = storage_client.bucket(zip_file_src.bucket.name).blob(zip_file_src.name)
#     zip_file = BytesIO()
#     zip_blob.download_to_file(zip_file)
#
#     # reset the position of the file object
#     zip_file.seek(0)
#
#     # open the zip file
#     with zipfile.ZipFile(zip_file, 'r') as zip_ref:
#         for file in zip_ref.namelist():
#             # create a BytesIO object from the file in the zip file
#             file_data = zip_ref.read(file)
#             file_stream = BytesIO(file_data)
#
#             # create a Google Cloud Storage blob from the BytesIO object
#             destination_blob = destination_folder + '/' + file
#             blob = bucket.blob(destination_blob)
#             blob.upload_from_file(file_stream)

# %% [raw]
# storage_client = storage.Client()
# zip_file_src = storage_client.bucket('finance-complaint-bucket').blob('complaints.json.zip')
# destination_bucket = 'finance-complaint-bucket'
# destination_folder = 'complaints.json'
# extract_zip_gcs_to_gcs(zip_file_src, destination_bucket, destination_folder)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Finance-Complaint').getOrCreate()

# %%
from pyspark.sql.functions import col, when

# read the JSON file
df = spark.read.json("gs://finance-complaint-bucket/complaints.json/complaints.json")

# replace empty strings with "null"
for col_name in df.columns:
    df = df.na.fill({col_name: "null"})
    df = df.withColumn(col_name, when(col(col_name) == "", "null").otherwise(col(col_name)))

# show the result
df.show()

# %%
# df.write.mode('append').parquet('gs://finance-complaint-bucket/parquet_file')

# %%
df = spark.read.parquet('gs://finance-complaint-bucket/parquet_file')

# %%
df.show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---------------+--------------------+-----------------------+--------------------+------------+-----------------------+-------------------------+-----------------+-------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+-------------+--------------+------+--------+
# |_corrupt_record|             company|company_public_response|    company_response|complaint_id|complaint_what_happened|consumer_consent_provided|consumer_disputed|date_received|date_sent_to_company|               issue|             product|state|           sub_issue|         sub_product|submitted_via|          tags|timely|zip_code|
# +---------------+--------------------+-----------------------+--------------------+------------+-----------------------+-------------------------+-----------------+-------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+-------------+--------------+------+--------+
# |           null|WELLS FARGO & COM...|   Company has respo...|Closed with expla...|     5178298|   We are currently ...|         Consent provided|              N/A|   2022-02-02|          2022-02-02|Applying for a mo...|            Mortgage|   CA|                null|Conventional home...|          Web|          null|   Yes|   95821|
# |           null|       EQUIFAX, INC.|                   null|Closed with expla...|     4569020|   Re : This is not ...|         Consent provided|              N/A|   2021-07-23|          2021-07-23|Incorrect informa...|Credit reporting,...|   LA|Information belon...|    Credit reporting|          Web|          null|   Yes|   70520|
# |           null|AMERICAN EXPRESS ...|                   null|Closed with non-m...|     2272516|   I have talked to ...|         Consent provided|               No|   2017-01-03|          2017-01-03|Customer service ...|         Credit card|   NY|                null|                null|          Web|          null|   Yes|   11415|
# |           null|PENTAGON FEDERAL ...|   Company has respo...|Closed with monet...|     2027052|   I have been a Pen...|         Consent provided|               No|   2016-07-25|          2016-07-26|Shopping for a lo...|       Consumer Loan|   CA|                null|    Installment loan|          Web|Older American|   Yes|   92562|
# |           null|Experian Informat...|   Company has respo...|Closed with non-m...|     1961647|   Experian is illeg...|         Consent provided|               No|   2016-06-09|          2016-06-09|Incorrect informa...|    Credit reporting|   CA|      Account status|                null|          Web| Servicemember|   Yes|   92308|
# |           null|CAPITAL ONE FINAN...|                   null|Closed with expla...|     5179596|                   null|     Consent not provided|              N/A|   2022-02-02|          2022-02-02|Getting a loan or...|Vehicle loan or l...|   PA|       Credit denial|                Loan|          Web|          null|   Yes|   19143|
# |           null|AMERICAN EXPRESS ...|                   null|Closed with expla...|     5177306|   I have reached ou...|         Consent provided|              N/A|   2022-02-02|          2022-02-02|Getting a credit ...|Credit card or pr...|   TX|  Application denied|General-purpose c...|          Web|          null|   Yes|   77021|
# |           null|JPMORGAN CHASE & CO.|                   null|Closed with expla...|     4550028|   Early in the mont...|         Consent provided|              N/A|   2021-07-16|          2021-07-16|Getting a credit ...|Credit card or pr...|   FL|  Application denied|General-purpose c...|          Web|          null|   Yes|   33308|
# |           null|Medical Data Syst...|   Company has respo...|Closed with expla...|     5177939|   Upon requesting w...|         Consent provided|              N/A|   2022-02-02|          2022-02-02|Written notificat...|     Debt collection|   GA|Didn't receive en...|        Medical debt|          Web| Servicemember|   Yes|   30101|
# |           null|   Lending Club Corp|                   null|Closed with expla...|     5176108|                   null|     Consent not provided|              N/A|   2022-02-02|          2022-02-02|Improper use of y...|Credit reporting,...|   CA|Reporting company...|    Credit reporting|          Web|          null|   Yes|   94303|
# |           null|Harris & Harris, ...|                   null|Closed with expla...|     4567296|   On XX/XX/XXXX HAR...|         Consent provided|              N/A|   2021-07-23|          2021-07-23|Improper use of y...|Credit reporting,...|   PA|Reporting company...|    Credit reporting|          Web|          null|   Yes|   19139|
# |           null|TRANSUNION INTERM...|   Company has respo...|Closed with expla...|     4568425|   I reviewed my cre...|         Consent provided|              N/A|   2021-07-22|          2021-07-22|Problem with a cr...|Credit reporting,...|   FL|Was not notified ...|    Credit reporting|          Web|          null|   Yes|   33409|
# |           null|              MOHELA|   Company believes ...|Closed with expla...|     1946964|   I have been makin...|         Consent provided|               No|   2016-05-31|          2016-05-31|Dealing with my l...|        Student loan|   CA|Trouble with how ...|Federal student l...|          Web|          null|   Yes|   94306|
# |           null|Ascension Point R...|                   null|Closed with expla...|     2183716|   Ascension Point c...|         Consent provided|               No|   2016-10-28|          2016-10-28|False statements ...|     Debt collection|   CO|Impersonated an a...|Other (i.e. phone...|          Web|          null|   Yes|   80204|
# |           null|WELLS FARGO & COM...|   Company has respo...|Closed with expla...|     2117621|   Special Forbearan...|         Consent provided|              Yes|   2016-09-17|          2016-09-17|Loan modification...|            Mortgage|   NV|                null|         VA mortgage|          Web|          null|   Yes|   89508|
# |           null|Utah System of Hi...|   Company has respo...|Closed with expla...|     1835598|   I had XXXX XXXX I...|         Consent provided|               No|   2016-03-16|          2016-04-03|Dealing with my l...|        Student loan|   FL|Received bad info...|Federal student l...|          Web|          null|   Yes|   32303|
# |           null|Shellpoint Partne...|   Company believes ...|Closed with expla...|     5034103|                   null|                    Other|              N/A|   2021-12-22|          2021-12-22|Struggling to pay...|            Mortgage|   NC|                null|Conventional home...|          Web|Older American|   Yes|   28694|
# |           null|WELLS FARGO & COM...|                   null|Closed with non-m...|      138611|                   null|                      N/A|               No|   2012-08-20|          2012-08-21|Account opening, ...|Bank account or s...|   MT|                null|    Checking account|          Web|          null|   Yes|   59701|
# |           null|       EQUIFAX, INC.|                   null|Closed with expla...|     2331310|                   null|     Consent not provided|               No|   2017-02-07|          2017-02-07|Incorrect informa...|    Credit reporting|   VA|Information is no...|                null|          Web|          null|   Yes|   22030|
# |           null|         GREAT LAKES|   Company believes ...|Closed with expla...|     2347021|                   null|     Consent not provided|               No|   2017-02-16|          2017-02-16| Can't repay my loan|        Student loan|   MI|Can't get flexibl...|Federal student l...|          Web|          null|   Yes|   48625|
# +---------------+--------------------+-----------------------+--------------------+------------+-----------------------+-------------------------+-----------------+-------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+-------------+--------------+------+--------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 3294357

# %%
from pyspark.sql.functions import col, when

for col_name in df.columns:
    df = df.withColumn(col_name, when(col(col_name) == "null", None).otherwise(col(col_name)))

# %%
from pyspark.sql.functions import col

# %%
df.select('complaint_id')
# Out:
# DataFrame[complaint_id: string]

# %% [markdown]
# ## Conf

# %%
def update_column_attribute(df):
    for column in df.columns:
        setattr(df, column, column)

# %%
update_column_attribute(df)

# %% [markdown]
# ## Printing unique values in each columns

# %%
for column in df.columns:
    print(f"{column}:{df.select(column).distinct().count()}")
# Out:
# _corrupt_record:3
# company:6628
# company_public_response:12
# company_response:9
# complaint_id:3294356
# complaint_what_happened:1032710
# consumer_consent_provided:6
# consumer_disputed:4
# date_received:4081
# date_sent_to_company:4030
# issue:166
# product:19
# state:64
# sub_issue:222
# sub_product:77
# submitted_via:8
# tags:4
# timely:3
# [Stage 113:===================================================>   (14 + 1) / 15]
# zip_code:34740

# %%
complaint_table = "complaint"
df.createOrReplaceTempView(complaint_table)

# %%
sql = spark.sql

# %%
n_row = df.count()
n_row
# Out:
# 3294357

# %%
# Target_column:
df.groupBy(df.consumer_disputed).count().show()
# Out:
# [Stage 122:===================================================>   (14 + 1) / 15]
# +-----------------+-------+
# |consumer_disputed|  count|
# +-----------------+-------+
# |             null|      2|
# |               No| 620049|
# |              N/A|2525928|
# |              Yes| 148378|
# +-----------------+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- company: string (nullable = true)
#  |-- company_public_response: string (nullable = true)
#  |-- company_response: string (nullable = true)
#  |-- complaint_id: string (nullable = true)
#  |-- complaint_what_happened: string (nullable = true)
#  |-- consumer_consent_provided: string (nullable = true)
#  |-- consumer_disputed: string (nullable = true)
#  |-- date_received: string (nullable = true)
#  |-- date_sent_to_company: string (nullable = true)
#  |-- issue: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- sub_issue: string (nullable = true)
#  |-- sub_product: string (nullable = true)
#  |-- submitted_via: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- timely: string (nullable = true)
#  |-- zip_code: string (nullable = true)

# %%
missing_target_df = sql(f"select * from {complaint_table} where {df.consumer_disputed}='N/A'")

# %%
df = sql(f"select * from {complaint_table} where {df.consumer_disputed}<>'N/A'")

# %%
df.count()
# Out:
# 768427

# %%
col_name = "complaint_what_happened"

# replace null values with "N/A"
df = df.withColumn(col_name, when(col(col_name).isNull(), "N/A").otherwise(col(col_name)))

# %%
complaint_table = 'complaint'
df.createOrReplaceTempView(complaint_table)

# %%
update_column_attribute(df)

# %%
def perform_null_analysis(df,table_name):
    null_value_analysis=[]
    n_row=df.count()
    for column in df.columns:
        print(column)
        response = sql(f"select {n_row} as  total_row,count(*) as null_row_{column},(count(*)*100)/{n_row} as missing_percentage,'{column}' as  column_name from {table_name} where {column} is null").collect()
        null_value_analysis.append(response)
    return null_value_analysis

# %%
null_report = perform_null_analysis(df, complaint_table)
# Out:
# _corrupt_record
# company
# company_public_response
# company_response
# complaint_id
# complaint_what_happened
# consumer_consent_provided
# consumer_disputed
# date_received
# date_sent_to_company
# issue
# product
# state
# sub_issue
# sub_product
# submitted_via
# tags
# timely
# zip_code

# %%
null_report
# Out:
# [[Row(total_row=768427, null_row__corrupt_record=768427, missing_percentage=100.0, column_name='_corrupt_record')],
#  [Row(total_row=768427, null_row_company=0, missing_percentage=0.0, column_name='company')],
#  [Row(total_row=768427, null_row_company_public_response=572718, missing_percentage=74.5312176693427, column_name='company_public_response')],
#  [Row(total_row=768427, null_row_company_response=0, missing_percentage=0.0, column_name='company_response')],
#  [Row(total_row=768427, null_row_complaint_id=0, missing_percentage=0.0, column_name='complaint_id')],
#  [Row(total_row=768427, null_row_complaint_what_happened=0, missing_percentage=0.0, column_name='complaint_what_happened')],
#  [Row(total_row=768427, null_row_consumer_consent_provided=38, missing_percentage=0.0049451672052127265, column_name='consumer_consent_provided')],
#  [Row(total_row=768427, null_row_consumer_disputed=0, missing_percentage=0.0, column_name='consumer_disputed')],
#  [Row(total_row=768427, null_row_date_received=0, missing_percentage=0.0, column_name='date_received')],
#  [Row(total_row=768427, null_row_date_sent_to_company=0, missing_percentage=0.0, column_name='date_sent_to_company')],
#  [Row(total_row=768427, null_row_issue=0, missing_percentage=0.0, column_name='issue')],
#  [Row(total_row=768427, null_row_product=0, missing_percentage=0.0, column_name='product')],
#  [Row(total_row=768427, null_row_state=5650, missing_percentage=0.7352682818276818, column_name='state')],
#  [Row(total_row=768427, null_row_sub_issue=455400, missing_percentage=59.26392487510199, column_name='sub_issue')],
#  [Row(total_row=768427, null_row_sub_product=235162, missing_percentage=30.603037113479875, column_name='sub_product')],
#  [Row(total_row=768427, null_row_submitted_via=0, missing_percentage=0.0, column_name='submitted_via')],
#  [Row(total_row=768427, null_row_tags=659931, missing_percentage=85.88076681324316, column_name='tags')],
#  [Row(total_row=768427, null_row_timely=0, missing_percentage=0.0, column_name='timely')],
#  [Row(total_row=768427, null_row_zip_code=5647, missing_percentage=0.7348778738904281, column_name='zip_code')]]

# %%
def unwanted_column_by_missing_pct(null_value_analysis, pct_thres=20):
    columns = []
    for row in null_value_analysis:
        row_info = row[0]
        if row_info.missing_percentage > pct_thres:
            print(row_info)
            columns.append(row_info.column_name)
    return columns

# %%
columns_unwanted = unwanted_column_by_missing_pct(null_report)
# Out:
# Row(total_row=768427, null_row__corrupt_record=768427, missing_percentage=100.0, column_name='_corrupt_record')
# Row(total_row=768427, null_row_company_public_response=572718, missing_percentage=74.5312176693427, column_name='company_public_response')
# Row(total_row=768427, null_row_sub_issue=455400, missing_percentage=59.26392487510199, column_name='sub_issue')
# Row(total_row=768427, null_row_sub_product=235162, missing_percentage=30.603037113479875, column_name='sub_product')
# Row(total_row=768427, null_row_tags=659931, missing_percentage=85.88076681324316, column_name='tags')

# %%
columns_unwanted
# Out:
# ['_corrupt_record',
#  'company_public_response',
#  'sub_issue',
#  'sub_product',
#  'tags']

# %%
df.columns
# Out:
# ['_corrupt_record',
#  'company',
#  'company_public_response',
#  'company_response',
#  'complaint_id',
#  'complaint_what_happened',
#  'consumer_consent_provided',
#  'consumer_disputed',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'product',
#  'state',
#  'sub_issue',
#  'sub_product',
#  'submitted_via',
#  'tags',
#  'timely',
#  'zip_code']

# %%
def drop_column(df, columns):
    selected_column = list(filter(lambda x:x not in columns, df.columns))
    selected_column = ",".join(selected_column)
    df = sql(f"select {selected_column} from {complaint_table}")
    return df

# %%
df = drop_column(df, columns_unwanted)

# %%
#dropping feature as we have found more than 20% of null value in above columns

# %%
df.collect()

# %%
# total number of rows:
df.count()
# Out:
# 768427

# %%
# unique values in each columns:

for column in df.columns:
    print(f"{column}:{df.select(column).distinct().count()}")
# Out:
# company:4282
# company_response:7
# complaint_id:768427
# complaint_what_happened:160961
# consumer_consent_provided:6
# consumer_disputed:2
# date_received:1970
# date_sent_to_company:2049
# issue:99
# product:13
# state:63
# submitted_via:6
# timely:2
# [Stage 490:===============================================>       (13 + 2) / 15]
# zip_code:28757

# %%
update_column_attribute(df)

# %%
df.printSchema()
# Out:
# root
#  |-- company: string (nullable = true)
#  |-- company_response: string (nullable = true)
#  |-- complaint_id: string (nullable = true)
#  |-- complaint_what_happened: string (nullable = true)
#  |-- consumer_consent_provided: string (nullable = true)
#  |-- consumer_disputed: string (nullable = true)
#  |-- date_received: timestamp (nullable = true)
#  |-- date_sent_to_company: timestamp (nullable = true)
#  |-- issue: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- submitted_via: string (nullable = true)
#  |-- timely: string (nullable = true)
#  |-- zip_code: string (nullable = true)

# %%
df.groupBy(df.company_response).count().show()
df.groupBy(df.consumer_consent_provided).count().show()
df.groupBy(df.consumer_disputed).count().show()
df.groupBy(df.product).count().show()
df.groupBy(df.submitted_via).count().show()
df.groupBy(df.timely).count().show()
# Out:
# +--------------------+------+
# |    company_response| count|
# +--------------------+------+
# |   Untimely response|  2870|
# |Closed with non-m...| 95432|
# |Closed without re...| 17868|
# |Closed with monet...| 51382|
# |Closed with expla...|577960|
# |              Closed| 17611|
# |  Closed with relief|  5304|
# +--------------------+------+
# +-------------------------+------+
# |consumer_consent_provided| count|
# +-------------------------+------+
# |                     null|    38|
# |        Consent withdrawn|     8|
# |                    Other|  8451|
# |         Consent provided|164082|
# |     Consent not provided|125338|
# |                      N/A|470510|
# +-------------------------+------+
# +-----------------+------+
# |consumer_disputed| count|
# +-----------------+------+
# |               No|620049|
# |              Yes|148378|
# +-----------------+------+
# +--------------------+------+
# |             product| count|
# +--------------------+------+
# |     Debt collection|145780|
# |    Virtual currency|    18|
# |         Payday loan|  5543|
# |     Money transfers|  5354|
# |Checking or savin...|     3|
# |            Mortgage|226894|
# |        Prepaid card|  3819|
# |    Credit reporting|140429|
# |       Consumer Loan| 31596|
# |         Credit card| 89190|
# |Bank account or s...| 86206|
# |Other financial s...|  1058|
# |        Student loan| 32537|
# +--------------------+------+
# +-------------+------+
# |submitted_via| count|
# +-------------+------+
# |        Phone| 52197|
# |          Fax| 10924|
# |        Email|   348|
# |     Referral|133247|
# |  Postal mail| 48672|
# |          Web|523039|
# +-------------+------+
#
# +------+------+
# |timely| count|
# +------+------+
# |    No| 21465|
# |   Yes|746962|
# +------+------+

# %%
df.groupBy(df.product).count().collect()
# Out:
# [Row(product='Debt collection', count=145780),
#  Row(product='Virtual currency', count=18),
#  Row(product='Payday loan', count=5543),
#  Row(product='Money transfers', count=5354),
#  Row(product='Checking or savings account', count=3),
#  Row(product='Mortgage', count=226894),
#  Row(product='Prepaid card', count=3819),
#  Row(product='Credit reporting', count=140429),
#  Row(product='Consumer Loan', count=31596),
#  Row(product='Credit card', count=89190),
#  Row(product='Bank account or service', count=86206),
#  Row(product='Other financial service', count=1058),
#  Row(product='Student loan', count=32537)]

# %%
#df.product no null value

# %% [markdown]
# ####  Feature Engineering Decision

# %%
ONE_HOT_FEATURE = [df.company_response, df.consumer_consent_provided, df.submitted_via, df.timely]
BINARY_ENCODING = [df.product]
TARGET_FEATURE = [df.consumer_disputed] #df.consumer_disputed target feature label encoding

# %%
from pyspark.sql.functions import count, isnull

column_name = 'company_response'

null_count = df.filter(isnull(df[column_name])).count()
null_count
#df.company_response No null value
# Out:
# 0

# %%
df.groupBy(df.consumer_consent_provided).count().show()
# Out:
# [Stage 538:===================================================>   (14 + 1) / 15]
# +-------------------------+------+
# |consumer_consent_provided| count|
# +-------------------------+------+
# |                     null|    38|
# |        Consent withdrawn|     8|
# |                    Other|  8451|
# |         Consent provided|164082|
# |     Consent not provided|125338|
# |                      N/A|470510|
# +-------------------------+------+

# %%
#df.consumer_consent_provided  replace null with top category

# %%
remaining_column = list(filter(lambda x:x not in ONE_HOT_FEATURE+BINARY_ENCODING+TARGET_FEATURE,df.columns))

# %%
remaining_column
# Out:
# ['company',
#  'complaint_id',
#  'complaint_what_happened',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'state',
#  'zip_code']

# %%
df.groupBy(df.company).count().show()
# Out:
# [Stage 545:===================================================>   (14 + 1) / 15]
# +--------------------+-----+
# |             company|count|
# +--------------------+-----+
# |FORD MOTOR CREDIT...|  477|
# |ATLANTIC COAST MO...|    2|
# |Eagle Home Mortga...|   65|
# |       PlusFour, Inc|   57|
# |   CU Recovery, Inc.|   19|
# |Delta Management ...|  109|
# |Law Office of Joe...|   27|
# |Praxis Financial ...|   50|
# |Worldwide Process...|   58|
# |Professional Serv...|    1|
# |National Recoveri...|   42|
# |SUN FINANCE COMPA...|    6|
# |           AFNI INC.| 1644|
# |Medical Data Syst...|  297|
# |A.R.M. Solutions,...|   73|
# |Law Office of Har...|   15|
# |Southern Credit R...|   37|
# |  DMB Financial, LLC|    4|
# |Capital Markets C...|   32|
# |   DCN Holdings Inc.|   23|
# +--------------------+-----+
# only showing top 20 rows

# %%
df.groupBy(df.company).count().count()
# Out:
# 4282

# %%
FREQUENCY_ENCODING = [df.company]

# %%
df.select(df.company).count() - df.select(df.company).dropna().count()
# Out:
# 0

# %%
column_name = 'zip_code'

null_count = df.filter(isnull(df[column_name])).count()
null_count
# Out:
# 5647

# %%
column_name = 'state'

null_count = df.filter(isnull(df[column_name])).count()
null_count
# Out:
# 5650

# %%
column_name = 'consumer_consent_provided'

null_count = df.filter(isnull(df[column_name])).count()
null_count
# Out:
# 38

# %%
REPLACE_NULL_WITH_TOP_VALUE = [df.zip_code, df.state, df.consumer_consent_provided]

# %%
REPLACE_NULL_WITH_TOP_VALUE
# Out:
# ['zip_code', 'state', 'consumer_consent_provided']

# %%
print(f"Total number of row: {df.count()}")
for column in remaining_column:
    print(f"{column}:  {df.select(column).distinct().count()}")
# Out:
# Total number of row: 768427
# company:  4282
# complaint_id:  768427
# complaint_what_happened:  160961
# date_received:  1970
# date_sent_to_company:  2049
# issue:  99
# state:  63
# [Stage 614:===================================================>   (14 + 1) / 15]
# zip_code:  28757

# %%
df.groupBy(df.issue).count().show()
# Out:
# [Stage 620:===================================================>   (14 + 1) / 15]
# +--------------------+------+
# |               issue| count|
# +--------------------+------+
# |Communication tac...| 23832|
# |Application proce...|   540|
# |Advertising and m...|  2959|
# |Balance transfer fee|   221|
# |        Adding money|   202|
# |Customer service/...|   283|
# |Closing/Cancellin...|  6389|
# |Credit card prote...|  2728|
# |Received a loan I...|   615|
# |Can't stop charge...|   510|
# |Forbearance / Wor...|   556|
# |          Bankruptcy|   448|
# |                Fees|   232|
# |Credit determination|  3057|
# |Loan modification...|112307|
# |    Cash advance fee|   196|
# |Other transaction...|  1491|
# |Customer service ...|  3504|
# |      Getting a loan|   664|
# |  Delinquent account|  3218|
# +--------------------+------+
# only showing top 20 rows

# %%
remaining_column
# Out:
# ['company',
#  'complaint_id',
#  'complaint_what_happened',
#  'date_received',
#  'date_sent_to_company',
#  'issue',
#  'state',
#  'zip_code']

# %%
sql(f"select {df.complaint_what_happened} from {complaint_table} limit 5").collect()
# Out:
# [Row(complaint_what_happened='I have talked to American Express customer service six times and their Credit Bureau Agency three times and they still have not removed the late payment status affecting my credit score. I have been in a relationship with American Express for eight years ( longer than any boyfriend I \'ve had! ) I was assured by XXXX in Customer Service three times over the phone that this late payment would be removed from my account. I had set up an auto pay and there must have been a computer glitch because the payment did not go through. This is XXXX payment over eight years, people! It was quickly rectified and my account has been in excellent standing ever since. \n\nWhen the late payment status was not removed, I called customer service again, and asked them to review the phone call with XXXX because they said they would n\'t remove the late payment. They said they would do so and I would get a phone call from a manager within XXXX to ten days. I never got a call from a manager. I called again and informed them of this and they said lackadaisically that they would listen to the recording " when they got around to it. \'\' It has been over four months that I \'ve been trying to get this resolved. \n\nWhen I talked to XXXX, he even three way called with their Credit Bureau Agency, so we were all on the same page. Please ask American Express to review this because they told me they would and they have not done so. I expected greater customer service from a prestigious company such as American Express.'),
#  Row(complaint_what_happened='I have been a Penfed Credit Union member over 8 years. I applied for $ XXXX signature loan, was denied, and the reason was too high loan balance? No explanation was given. The only account I have with Penfed C.U. is a $ XXXX XXXX, with a balance the was was $ XXXX, but has been paid down to {$6700.00}. My wife is a retired XXXX with a XXXX month pension and I am semi-retired with {$1300.00} monthly Social Security and I work part-time as a XXXX with {$3500.00} monthly additional income. Our mortgage payment is XXXX monthly, plus some smaller monthly payments.The Penfed phone employee did not listen to me and my reason for the installment loan request. I personally felt age discrimination. Please follow-up with Penfed.'),
#  Row(complaint_what_happened='Experian is illegally reporting a medical collection account for XXXX XXXX that was never validated per Fair Debt Collections Practices Act. I was never contacted and I have asked for a complete accounting of the debt but they have failed to respond. Experian should have some checks and balances to ensure that a creditor has in fact obeyed the law before allowing them to report a negative mark.'),
#  Row(complaint_what_happened="I have been making payments to Mohela while I 'm in school. They are missing XXXX of my payments according to their website. It is very difficult to comprehend payments received on their website. I 've asked for an itemized list of ALL my payments and they do n't seem to be able to send it. I 've verified with my bank, XXXX, that they have received all my payments. I can send a list of my payments from my bank if needed. They should be able to provide a document saying what I 've paid to date so I can match that with my bank."),
#  Row(complaint_what_happened='Ascension Point called me from a XXXX - XXXX telling me they were looking for someone who was the executor of my dad \'s estate. They would n\'t tell me what it was about until I said I was the executor. She would n\'t tell me what it was about and did n\'t know my name. I said, " how can you cold call my number about my dead dad \'s estate and not know my XXXX name? \'\' she did n\'t have an answer and that \'s when I XXXX it and saw the scam reviews.')]

# %%
TOKENIZER_FEATURE = [df.complaint_what_happened]

# %%
ONE_HOT_FEATURE
# Out:
# ['company_response', 'consumer_consent_provided', 'submitted_via', 'timely']

# %%
FREQUENCY_ENCODING = [df.company,df.issue,df.state,df.zip_code]

# %%
from pyspark.sql.types import TimestampType

# %%
df=df.withColumn(df.date_received,col(df.date_received).cast(TimestampType()))

# %%
update_column_attribute(df)

# %%
df=df.withColumn(df.date_sent_to_company,col(df.date_sent_to_company).cast(TimestampType()))
df.printSchema()
# Out:
# root
#  |-- company: string (nullable = true)
#  |-- company_response: string (nullable = true)
#  |-- complaint_id: string (nullable = true)
#  |-- complaint_what_happened: string (nullable = true)
#  |-- consumer_consent_provided: string (nullable = true)
#  |-- consumer_disputed: string (nullable = true)
#  |-- date_received: timestamp (nullable = true)
#  |-- date_sent_to_company: timestamp (nullable = true)
#  |-- issue: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- submitted_via: string (nullable = true)
#  |-- timely: string (nullable = true)
#  |-- zip_code: string (nullable = true)

# %%
df.select([df.date_received,df.date_sent_to_company]).show()
# Out:
# +-------------------+--------------------+
# |      date_received|date_sent_to_company|
# +-------------------+--------------------+
# |2017-01-03 00:00:00| 2017-01-03 00:00:00|
# |2016-07-25 00:00:00| 2016-07-26 00:00:00|
# |2016-06-09 00:00:00| 2016-06-09 00:00:00|
# |2016-05-31 00:00:00| 2016-05-31 00:00:00|
# |2016-10-28 00:00:00| 2016-10-28 00:00:00|
# |2016-09-17 00:00:00| 2016-09-17 00:00:00|
# |2016-03-16 00:00:00| 2016-04-03 00:00:00|
# |2012-08-20 00:00:00| 2012-08-21 00:00:00|
# |2017-02-07 00:00:00| 2017-02-07 00:00:00|
# |2017-02-16 00:00:00| 2017-02-16 00:00:00|
# |2014-10-03 00:00:00| 2014-10-08 00:00:00|
# |2016-08-06 00:00:00| 2016-08-06 00:00:00|
# |2016-10-20 00:00:00| 2016-10-20 00:00:00|
# |2016-05-24 00:00:00| 2016-05-31 00:00:00|
# |2013-09-30 00:00:00| 2013-10-01 00:00:00|
# |2013-11-12 00:00:00| 2013-11-12 00:00:00|
# |2015-08-12 00:00:00| 2015-08-12 00:00:00|
# |2015-07-16 00:00:00| 2015-07-16 00:00:00|
# |2017-02-02 00:00:00| 2017-02-02 00:00:00|
# |2014-08-04 00:00:00| 2014-08-04 00:00:00|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.types import  LongType

# %%
df = df.withColumn("diff_in_days",(col(df.date_sent_to_company).cast(LongType())-col(df.date_received).cast(LongType()))/(60*60*24))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df = df.withColumn("diff_in_days",(col(df.date_sent_to_company).cast(LongType())-col(df.date_received).cast(LongType()))/(60*60*24))
#
# File /usr/lib/spark/python/pyspark/sql/functions.py:112, in col(col)
#     101 @since(1.3)
#     102 def col(col):
#     103     """
#     104     Returns a :class:`~pyspark.sql.Column` based on the given column name.'
#     105     Examples
#    (...)
#     110     Column<'x'>
#     111     """
# --> 112     return _invoke_function("col", col)
#
# File /usr/lib/spark/python/pyspark/sql/functions.py:58, in _invoke_function(name, *args)
#      53 """
#      54 Invokes JVM function identified by name with args
#      55 and wraps the result with :class:`~pyspark.sql.Column`.
#      56 """
#      57 jf = _get_get_jvm_function(name, SparkContext._active_spark_context)
# ---> 58 return Column(jf(*args))
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1296, in JavaMember.__call__(self, *args)
#    1295 def __call__(self, *args):
# -> 1296     args_command, temp_args = self._build_args(*args)
#    1298     command = proto.CALL_COMMAND_NAME +\
#    1299         self.command_header +\
#    1300         args_command +\
#    1301         proto.END_COMMAND_PART
#    1303     answer = self.gateway_client.send_command(command)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1260, in JavaMember._build_args(self, *args)
#    1258 def _build_args(self, *args):
#    1259     if self.converters is not None and len(self.converters) > 0:
# -> 1260         (new_args, temp_args) = self._get_args(args)
#    1261     else:
#    1262         new_args = args
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1247, in JavaMember._get_args(self, args)
#    1245 for converter in self.gateway_client.converters:
#    1246     if converter.can_convert(arg):
# -> 1247         temp_arg = converter.convert(arg, self.gateway_client)
#    1248         temp_args.append(temp_arg)
#    1249         new_args.append(temp_arg)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_collections.py:510, in ListConverter.convert(self, object, gateway_client)
#     508 ArrayList = JavaClass("java.util.ArrayList", gateway_client)
#     509 java_list = ArrayList()
# --> 510 for element in object:
#     511     java_list.add(element)
#     512 return java_list
#
# File /usr/lib/spark/python/pyspark/sql/column.py:461, in Column.__iter__(self)
#     460 def __iter__(self):
# --> 461     raise TypeError("Column is not iterable")
#
# TypeError: Column is not iterable

# %%
df = df.withColumn("diff_in_days", (col(df.date_sent_to_company).cast(LongType())-col(df.date_received).cast(LongType()))/(60*60*24)).alias("diff_in_days")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df = df.withColumn("diff_in_days", (col(df.date_sent_to_company).cast(LongType())-col(df.date_received).cast(LongType()))/(60*60*24)).alias("diff_in_days")
#
# File /usr/lib/spark/python/pyspark/sql/functions.py:112, in col(col)
#     101 @since(1.3)
#     102 def col(col):
#     103     """
#     104     Returns a :class:`~pyspark.sql.Column` based on the given column name.'
#     105     Examples
#    (...)
#     110     Column<'x'>
#     111     """
# --> 112     return _invoke_function("col", col)
#
# File /usr/lib/spark/python/pyspark/sql/functions.py:58, in _invoke_function(name, *args)
#      53 """
#      54 Invokes JVM function identified by name with args
#      55 and wraps the result with :class:`~pyspark.sql.Column`.
#      56 """
#      57 jf = _get_get_jvm_function(name, SparkContext._active_spark_context)
# ---> 58 return Column(jf(*args))
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1296, in JavaMember.__call__(self, *args)
#    1295 def __call__(self, *args):
# -> 1296     args_command, temp_args = self._build_args(*args)
#    1298     command = proto.CALL_COMMAND_NAME +\
#    1299         self.command_header +\
#    1300         args_command +\
#    1301         proto.END_COMMAND_PART
#    1303     answer = self.gateway_client.send_command(command)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1260, in JavaMember._build_args(self, *args)
#    1258 def _build_args(self, *args):
#    1259     if self.converters is not None and len(self.converters) > 0:
# -> 1260         (new_args, temp_args) = self._get_args(args)
#    1261     else:
#    1262         new_args = args
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py:1247, in JavaMember._get_args(self, args)
#    1245 for converter in self.gateway_client.converters:
#    1246     if converter.can_convert(arg):
# -> 1247         temp_arg = converter.convert(arg, self.gateway_client)
#    1248         temp_args.append(temp_arg)
#    1249         new_args.append(temp_arg)
#
# File /usr/lib/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_collections.py:510, in ListConverter.convert(self, object, gateway_client)
#     508 ArrayList = JavaClass("java.util.ArrayList", gateway_client)
#     509 java_list = ArrayList()
# --> 510 for element in object:
#     511     java_list.add(element)
#     512 return java_list
#
# File /usr/lib/spark/python/pyspark/sql/column.py:461, in Column.__iter__(self)
#     460 def __iter__(self):
# --> 461     raise TypeError("Column is not iterable")
#
# TypeError: Column is not iterable

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import LongType

df = df.withColumn("diff_in_days", (col("date_sent_to_company").cast(LongType())-col("date_received").cast(LongType()))/(60*60*24)).alias("diff_in_days")

# %%
update_column_attribute(df)

# %%
remove_column = [df.date_received,df.date_sent_to_company]

# %%
df=df.drop(col(df.date_received)).drop(col(df.date_sent_to_company))

# %%
df.show()
# Out:
# +--------------------+--------------------+------------+-----------------------+-------------------------+-----------------+--------------------+--------------------+-----+-------------+------+--------+------------+
# |             company|    company_response|complaint_id|complaint_what_happened|consumer_consent_provided|consumer_disputed|               issue|             product|state|submitted_via|timely|zip_code|diff_in_days|
# +--------------------+--------------------+------------+-----------------------+-------------------------+-----------------+--------------------+--------------------+-----+-------------+------+--------+------------+
# |AMERICAN EXPRESS ...|Closed with non-m...|     2272516|   I have talked to ...|         Consent provided|               No|Customer service ...|         Credit card|   NY|          Web|   Yes|   11415|         0.0|
# |PENTAGON FEDERAL ...|Closed with monet...|     2027052|   I have been a Pen...|         Consent provided|               No|Shopping for a lo...|       Consumer Loan|   CA|          Web|   Yes|   92562|         1.0|
# |Experian Informat...|Closed with non-m...|     1961647|   Experian is illeg...|         Consent provided|               No|Incorrect informa...|    Credit reporting|   CA|          Web|   Yes|   92308|         0.0|
# |              MOHELA|Closed with expla...|     1946964|   I have been makin...|         Consent provided|               No|Dealing with my l...|        Student loan|   CA|          Web|   Yes|   94306|         0.0|
# |Ascension Point R...|Closed with expla...|     2183716|   Ascension Point c...|         Consent provided|               No|False statements ...|     Debt collection|   CO|          Web|   Yes|   80204|         0.0|
# |WELLS FARGO & COM...|Closed with expla...|     2117621|   Special Forbearan...|         Consent provided|              Yes|Loan modification...|            Mortgage|   NV|          Web|   Yes|   89508|         0.0|
# |Utah System of Hi...|Closed with expla...|     1835598|   I had XXXX XXXX I...|         Consent provided|               No|Dealing with my l...|        Student loan|   FL|          Web|   Yes|   32303|        18.0|
# |WELLS FARGO & COM...|Closed with non-m...|      138611|                    N/A|                      N/A|               No|Account opening, ...|Bank account or s...|   MT|          Web|   Yes|   59701|         1.0|
# |       EQUIFAX, INC.|Closed with expla...|     2331310|                    N/A|     Consent not provided|               No|Incorrect informa...|    Credit reporting|   VA|          Web|   Yes|   22030|         0.0|
# |         GREAT LAKES|Closed with expla...|     2347021|                    N/A|     Consent not provided|               No| Can't repay my loan|        Student loan|   MI|          Web|   Yes|   48625|         0.0|
# |      CITIBANK, N.A.|Closed with expla...|     1057213|                    N/A|                      N/A|               No|Loan modification...|            Mortgage|   MA|     Referral|   Yes|   20912|         5.0|
# |       EQUIFAX, INC.|Closed with expla...|     2049846|   I have contacted ...|         Consent provided|               No|Credit reporting ...|    Credit reporting|   GA|          Web|   Yes|   30906|         0.0|
# |       EQUIFAX, INC.|Closed with expla...|     2170080|   To Whom It May Co...|         Consent provided|              Yes|Incorrect informa...|    Credit reporting|   NY|          Web|   Yes|   11423|         0.0|
# |        U.S. BANCORP|Closed with expla...|     1939199|   XXXX we submitted...|         Consent provided|               No|Loan modification...|            Mortgage|   VA|          Web|   Yes|   20186|         7.0|
# |Ocwen Financial C...|Closed with expla...|      547853|                    N/A|                      N/A|               No|Loan modification...|            Mortgage|   NC|          Web|   Yes|   27520|         1.0|
# |Zakheim Law Group...|Closed with expla...|      593190|                    N/A|                      N/A|               No|Disclosure verifi...|     Debt collection|   GA|          Web|   Yes|   30534|         0.0|
# |WELLS FARGO & COM...|Closed with expla...|     1514766|   I have a personal...|         Consent provided|               No|Taking/threatenin...|     Debt collection|   TX|          Web|   Yes|   76155|         0.0|
# |HSBC NORTH AMERIC...|Closed with expla...|     1471844|   Called me at XXXX...|         Consent provided|               No|Communication tac...|     Debt collection|   PA|          Web|   Yes|   19015|         0.0|
# |Navient Solutions...|Closed with expla...|     2323172|                    N/A|     Consent not provided|               No| Can't repay my loan|        Student loan|   KY|          Web|   Yes|   42301|         0.0|
# |Ocwen Financial C...|Closed with expla...|      966328|                    N/A|                      N/A|              Yes|Loan modification...|            Mortgage|   CA|          Web|    No|   95640|         0.0|
# +--------------------+--------------------+------------+-----------------------+-------------------------+-----------------+--------------------+--------------------+-----+-------------+------+--------+------------+
# only showing top 20 rows

# %%
NUMERICAL_FEATURE = [df.diff_in_days,]
ONE_HOT_FEATURE+\
FREQUENCY_ENCODING+\
BINARY_ENCODING+\
TARGET_FEATURE
# Out:
# ['company_response',
#  'consumer_consent_provided',
#  'submitted_via',
#  'timely',
#  'company',
#  'issue',
#  'state',
#  'zip_code',
#  'product',
#  'consumer_disputed']

# %%
BINARY_ENCODING
# Out:
# ['product']

# %%
FREQUENCY_ENCODING=FREQUENCY_ENCODING+BINARY_ENCODING

# %%
FREQUENCY_ENCODING.remove('issue')

# %%
FREQUENCY_ENCODING
# Out:
# ['company', 'state', 'zip_code', 'product']

# %%
ONE_HOT_FEATURE
# Out:
# ['company_response', 'consumer_consent_provided', 'submitted_via', 'timely']
